# %%
import pandas as pd

data = pd.read_csv("metacritic_all_games_with_ign_reviews_corrected.csv")
data.head()
# Out:
#                                    name        platform        release_date  \
# 0  The Legend of Zelda: Ocarina of Time     Nintendo 64   November 23, 1998
# 1              Tony Hawk's Pro Skater 2     PlayStation  September 20, 2000
# 2                   Grand Theft Auto IV   PlayStation 3      April 29, 2008
# 3                           SoulCalibur       Dreamcast   September 8, 1999
# 4                   Grand Theft Auto IV        Xbox 360      April 29, 2008
#
#                                              summary  meta_score  user_review  \
# 0  As a young boy, Link is tricked by Ganondorf, ...          99          9.1
# 1  As most major publishers' development efforts ...          98          7.4
# 2  [Metacritic's 2008 PS3 Game of the Year; Also ...          98          7.7
# 3  This is a tale of souls and swords, transcendi...          98          8.4
# 4  [Metacritic's 2008 Xbox 360 Game of the Year; ...          98          7.9
#
#                                           ign_review
# 0  The new benchmark for interactive entertainmen...
# 1  I'm going to try to make this short and sweet,...
# 2  Criminals are an ugly, cowardly lot more worth...
# 3  I'm reviewing Soul Calibur in a somewhat biase...
# 4  Criminals are an ugly, cowardly lot more worth...

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuation(text):
    punctuationfree="".join([i for i in text if i not in string.punctuation])
    return punctuationfree

data['clean_review']= data['ign_review'].apply(lambda x:remove_punctuation(x))
data.head()
# Out:
#                                    name        platform        release_date  \
# 0  The Legend of Zelda: Ocarina of Time     Nintendo 64   November 23, 1998
# 1              Tony Hawk's Pro Skater 2     PlayStation  September 20, 2000
# 2                   Grand Theft Auto IV   PlayStation 3      April 29, 2008
# 3                           SoulCalibur       Dreamcast   September 8, 1999
# 4                   Grand Theft Auto IV        Xbox 360      April 29, 2008
#
#                                              summary  meta_score  user_review  \
# 0  As a young boy, Link is tricked by Ganondorf, ...          99          9.1
# 1  As most major publishers' development efforts ...          98          7.4
# 2  [Metacritic's 2008 PS3 Game of the Year; Also ...          98          7.7
# 3  This is a tale of souls and swords, transcendi...          98          8.4
# 4  [Metacritic's 2008 Xbox 360 Game of the Year; ...          98          7.9
#
#                                           ign_review  \
# 0  The new benchmark for interactive entertainmen...
# 1  I'm going to try to make this short and sweet,...
# 2  Criminals are an ugly, cowardly lot more worth...
# 3  I'm reviewing Soul Calibur in a somewhat biase...
# 4  Criminals are an ugly, cowardly lot more worth...
#
#                                         clean_review
# 0  The new benchmark for interactive entertainmen...
# 1  Im going to try to make this short and sweet b...
# 2  Criminals are an ugly cowardly lot more worthy...
# 3  Im reviewing Soul Calibur in a somewhat biased...
# 4  Criminals are an ugly cowardly lot more worthy...

# %%
data['review_lowerc']= data['clean_review'].apply(lambda x: x.lower())
data.head()
# Out:
#                                    name        platform        release_date  \
# 0  The Legend of Zelda: Ocarina of Time     Nintendo 64   November 23, 1998
# 1              Tony Hawk's Pro Skater 2     PlayStation  September 20, 2000
# 2                   Grand Theft Auto IV   PlayStation 3      April 29, 2008
# 3                           SoulCalibur       Dreamcast   September 8, 1999
# 4                   Grand Theft Auto IV        Xbox 360      April 29, 2008
#
#                                              summary  meta_score  user_review  \
# 0  As a young boy, Link is tricked by Ganondorf, ...          99          9.1
# 1  As most major publishers' development efforts ...          98          7.4
# 2  [Metacritic's 2008 PS3 Game of the Year; Also ...          98          7.7
# 3  This is a tale of souls and swords, transcendi...          98          8.4
# 4  [Metacritic's 2008 Xbox 360 Game of the Year; ...          98          7.9
#
#                                           ign_review  \
# 0  The new benchmark for interactive entertainmen...
# 1  I'm going to try to make this short and sweet,...
# 2  Criminals are an ugly, cowardly lot more worth...
# 3  I'm reviewing Soul Calibur in a somewhat biase...
# 4  Criminals are an ugly, cowardly lot more worth...
#
#                                         clean_review  \
# 0  The new benchmark for interactive entertainmen...
# 1  Im going to try to make this short and sweet b...
# 2  Criminals are an ugly cowardly lot more worthy...
# 3  Im reviewing Soul Calibur in a somewhat biased...
# 4  Criminals are an ugly cowardly lot more worthy...
#
#                                        review_lowerc
# 0  the new benchmark for interactive entertainmen...
# 1  im going to try to make this short and sweet b...
# 2  criminals are an ugly cowardly lot more worthy...
# 3  im reviewing soul calibur in a somewhat biased...
# 4  criminals are an ugly cowardly lot more worthy...

# %%
from nltk import word_tokenize, sent_tokenize

data['review_token']= data['review_lowerc'].apply(lambda x: word_tokenize(x))
data.head()
# Out:
#                                    name        platform        release_date  \
# 0  The Legend of Zelda: Ocarina of Time     Nintendo 64   November 23, 1998
# 1              Tony Hawk's Pro Skater 2     PlayStation  September 20, 2000
# 2                   Grand Theft Auto IV   PlayStation 3      April 29, 2008
# 3                           SoulCalibur       Dreamcast   September 8, 1999
# 4                   Grand Theft Auto IV        Xbox 360      April 29, 2008
#
#                                              summary  meta_score  user_review  \
# 0  As a young boy, Link is tricked by Ganondorf, ...          99          9.1
# 1  As most major publishers' development efforts ...          98          7.4
# 2  [Metacritic's 2008 PS3 Game of the Year; Also ...          98          7.7
# 3  This is a tale of souls and swords, transcendi...          98          8.4
# 4  [Metacritic's 2008 Xbox 360 Game of the Year; ...          98          7.9
#
#                                           ign_review  \
# 0  The new benchmark for interactive entertainmen...
# 1  I'm going to try to make this short and sweet,...
# 2  Criminals are an ugly, cowardly lot more worth...
# 3  I'm reviewing Soul Calibur in a somewhat biase...
# 4  Criminals are an ugly, cowardly lot more worth...
#
#                                         clean_review  \
# 0  The new benchmark for interactive entertainmen...
# 1  Im going to try to make this short and sweet b...
# 2  Criminals are an ugly cowardly lot more worthy...
# 3  Im reviewing Soul Calibur in a somewhat biased...
# 4  Criminals are an ugly cowardly lot more worthy...
#
#                                        review_lowerc  \
# 0  the new benchmark for interactive entertainmen...
# 1  im going to try to make this short and sweet b...
# 2  criminals are an ugly cowardly lot more worthy...
# 3  im reviewing soul calibur in a somewhat biased...
# 4  criminals are an ugly cowardly lot more worthy...
#
#                                         review_token
# 0  [the, new, benchmark, for, interactive, entert...
# 1  [im, going, to, try, to, make, this, short, an...
# 2  [criminals, are, an, ugly, cowardly, lot, more...
# 3  [im, reviewing, soul, calibur, in, a, somewhat...
# 4  [criminals, are, an, ugly, cowardly, lot, more...

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

# %%
def remove_stopwords(text):
    output= [i for i in text if i not in stop_words]
    return output

data['review_stopwords']= data['review_token'].apply(lambda x:remove_stopwords(x))

# %%
data.head()
# Out:
#                                    name        platform        release_date  \
# 0  The Legend of Zelda: Ocarina of Time     Nintendo 64   November 23, 1998
# 1              Tony Hawk's Pro Skater 2     PlayStation  September 20, 2000
# 2                   Grand Theft Auto IV   PlayStation 3      April 29, 2008
# 3                           SoulCalibur       Dreamcast   September 8, 1999
# 4                   Grand Theft Auto IV        Xbox 360      April 29, 2008
#
#                                              summary  meta_score  user_review  \
# 0  As a young boy, Link is tricked by Ganondorf, ...          99          9.1
# 1  As most major publishers' development efforts ...          98          7.4
# 2  [Metacritic's 2008 PS3 Game of the Year; Also ...          98          7.7
# 3  This is a tale of souls and swords, transcendi...          98          8.4
# 4  [Metacritic's 2008 Xbox 360 Game of the Year; ...          98          7.9
#
#                                           ign_review  \
# 0  The new benchmark for interactive entertainmen...
# 1  I'm going to try to make this short and sweet,...
# 2  Criminals are an ugly, cowardly lot more worth...
# 3  I'm reviewing Soul Calibur in a somewhat biase...
# 4  Criminals are an ugly, cowardly lot more worth...
#
#                                         clean_review  \
# 0  The new benchmark for interactive entertainmen...
# 1  Im going to try to make this short and sweet b...
# 2  Criminals are an ugly cowardly lot more worthy...
# 3  Im reviewing Soul Calibur in a somewhat biased...
# 4  Criminals are an ugly cowardly lot more worthy...
#
#                                        review_lowerc  \
# 0  the new benchmark for interactive entertainmen...
# 1  im going to try to make this short and sweet b...
# 2  criminals are an ugly cowardly lot more worthy...
# 3  im reviewing soul calibur in a somewhat biased...
# 4  criminals are an ugly cowardly lot more worthy...
#
#                                         review_token  \
# 0  [the, new, benchmark, for, interactive, entert...
# 1  [im, going, to, try, to, make, this, short, an...
# 2  [criminals, are, an, ugly, cowardly, lot, more...
# 3  [im, reviewing, soul, calibur, in, a, somewhat...
# 4  [criminals, are, an, ugly, cowardly, lot, more...
#
#                                     review_stopwords
# 0  [new, benchmark, interactive, entertainment, a...
# 1  [im, going, try, make, short, sweet, im, neith...
# 2  [criminals, ugly, cowardly, lot, worthy, pity,...
# 3  [im, reviewing, soul, calibur, somewhat, biase...
# 4  [criminals, ugly, cowardly, lot, worthy, pity,...

# %%
from nltk.stem.porter import PorterStemmer
porter_stemmer = PorterStemmer()

def stemming(text):
    stem_text = [porter_stemmer.stem(word) for word in text]
    return stem_text
data['review_stemmed']=data['review_stopwords'].apply(lambda x: stemming(x))

# %%
data.head()
# Out:
#                                    name        platform        release_date  \
# 0  The Legend of Zelda: Ocarina of Time     Nintendo 64   November 23, 1998
# 1              Tony Hawk's Pro Skater 2     PlayStation  September 20, 2000
# 2                   Grand Theft Auto IV   PlayStation 3      April 29, 2008
# 3                           SoulCalibur       Dreamcast   September 8, 1999
# 4                   Grand Theft Auto IV        Xbox 360      April 29, 2008
#
#                                              summary  meta_score  user_review  \
# 0  As a young boy, Link is tricked by Ganondorf, ...          99          9.1
# 1  As most major publishers' development efforts ...          98          7.4
# 2  [Metacritic's 2008 PS3 Game of the Year; Also ...          98          7.7
# 3  This is a tale of souls and swords, transcendi...          98          8.4
# 4  [Metacritic's 2008 Xbox 360 Game of the Year; ...          98          7.9
#
#                                           ign_review  \
# 0  The new benchmark for interactive entertainmen...
# 1  I'm going to try to make this short and sweet,...
# 2  Criminals are an ugly, cowardly lot more worth...
# 3  I'm reviewing Soul Calibur in a somewhat biase...
# 4  Criminals are an ugly, cowardly lot more worth...
#
#                                         clean_review  \
# 0  The new benchmark for interactive entertainmen...
# 1  Im going to try to make this short and sweet b...
# 2  Criminals are an ugly cowardly lot more worthy...
# 3  Im reviewing Soul Calibur in a somewhat biased...
# 4  Criminals are an ugly cowardly lot more worthy...
#
#                                        review_lowerc  \
# 0  the new benchmark for interactive entertainmen...
# 1  im going to try to make this short and sweet b...
# 2  criminals are an ugly cowardly lot more worthy...
# 3  im reviewing soul calibur in a somewhat biased...
# 4  criminals are an ugly cowardly lot more worthy...
#
#                                         review_token  \
# 0  [the, new, benchmark, for, interactive, entert...
# 1  [im, going, to, try, to, make, this, short, an...
# 2  [criminals, are, an, ugly, cowardly, lot, more...
# 3  [im, reviewing, soul, calibur, in, a, somewhat...
# 4  [criminals, are, an, ugly, cowardly, lot, more...
#
#                                     review_stopwords  \
# 0  [new, benchmark, interactive, entertainment, a...
# 1  [im, going, try, make, short, sweet, im, neith...
# 2  [criminals, ugly, cowardly, lot, worthy, pity,...
# 3  [im, reviewing, soul, calibur, somewhat, biase...
# 4  [criminals, ugly, cowardly, lot, worthy, pity,...
#
#                                       review_stemmed
# 0  [new, benchmark, interact, entertain, arriv, l...
# 1  [im, go, tri, make, short, sweet, im, neither,...
# 2  [crimin, ugli, cowardli, lot, worthi, piti, di...
# 3  [im, review, soul, calibur, somewhat, bias, st...
# 4  [crimin, ugli, cowardli, lot, worthi, piti, di...

# %%
from nltk.stem import WordNetLemmatizer

wordnet_lemmatizer = WordNetLemmatizer()

# %%
def lemmatizer(text):
    lemm_text = [wordnet_lemmatizer.lemmatize(word) for word in text]
    return lemm_text
data['review_lemmatized']=data['review_stopwords'].apply(lambda x:lemmatizer(x))

# %%
data.head()
# Out:
#                                    name        platform        release_date  \
# 0  The Legend of Zelda: Ocarina of Time     Nintendo 64   November 23, 1998
# 1              Tony Hawk's Pro Skater 2     PlayStation  September 20, 2000
# 2                   Grand Theft Auto IV   PlayStation 3      April 29, 2008
# 3                           SoulCalibur       Dreamcast   September 8, 1999
# 4                   Grand Theft Auto IV        Xbox 360      April 29, 2008
#
#                                              summary  meta_score  user_review  \
# 0  As a young boy, Link is tricked by Ganondorf, ...          99          9.1
# 1  As most major publishers' development efforts ...          98          7.4
# 2  [Metacritic's 2008 PS3 Game of the Year; Also ...          98          7.7
# 3  This is a tale of souls and swords, transcendi...          98          8.4
# 4  [Metacritic's 2008 Xbox 360 Game of the Year; ...          98          7.9
#
#                                           ign_review  \
# 0  The new benchmark for interactive entertainmen...
# 1  I'm going to try to make this short and sweet,...
# 2  Criminals are an ugly, cowardly lot more worth...
# 3  I'm reviewing Soul Calibur in a somewhat biase...
# 4  Criminals are an ugly, cowardly lot more worth...
#
#                                         clean_review  \
# 0  The new benchmark for interactive entertainmen...
# 1  Im going to try to make this short and sweet b...
# 2  Criminals are an ugly cowardly lot more worthy...
# 3  Im reviewing Soul Calibur in a somewhat biased...
# 4  Criminals are an ugly cowardly lot more worthy...
#
#                                        review_lowerc  \
# 0  the new benchmark for interactive entertainmen...
# 1  im going to try to make this short and sweet b...
# 2  criminals are an ugly cowardly lot more worthy...
# 3  im reviewing soul calibur in a somewhat biased...
# 4  criminals are an ugly cowardly lot more worthy...
#
#                                         review_token  \
# 0  [the, new, benchmark, for, interactive, entert...
# 1  [im, going, to, try, to, make, this, short, an...
# 2  [criminals, are, an, ugly, cowardly, lot, more...
# 3  [im, reviewing, soul, calibur, in, a, somewhat...
# 4  [criminals, are, an, ugly, cowardly, lot, more...
#
#                                     review_stopwords  \
# 0  [new, benchmark, interactive, entertainment, a...
# 1  [im, going, try, make, short, sweet, im, neith...
# 2  [criminals, ugly, cowardly, lot, worthy, pity,...
# 3  [im, reviewing, soul, calibur, somewhat, biase...
# 4  [criminals, ugly, cowardly, lot, worthy, pity,...
#
#                                       review_stemmed  \
# 0  [new, benchmark, interact, entertain, arriv, l...
# 1  [im, go, tri, make, short, sweet, im, neither,...
# 2  [crimin, ugli, cowardli, lot, worthi, piti, di...
# 3  [im, review, soul, calibur, somewhat, bias, st...
# 4  [crimin, ugli, cowardli, lot, worthi, piti, di...
#
#                                    review_lemmatized
# 0  [new, benchmark, interactive, entertainment, a...
# 1  [im, going, try, make, short, sweet, im, neith...
# 2  [criminal, ugly, cowardly, lot, worthy, pity, ...
# 3  [im, reviewing, soul, calibur, somewhat, biase...
# 4  [criminal, ugly, cowardly, lot, worthy, pity, ...

# %%
data.to_csv('data_preprocessed.csv')

# %%
data['sentiment'] = data['meta_score'].apply(lambda meta_score : +1 if meta_score >= 50 else -1)
data[data.sentiment == -1]
# Out:
#                                                     name        platform  \
# 10209                                   Those Who Remain        Xbox 360
# 10210                                      My Horse & Me              PC
# 10211               Transformers: Rise of the Dark Spark              DS
# 10212  Codename: Kids Next Door: Operation V.I.D.E.O....   PlayStation 2
# 10213       Teenage Mutant Ninja Turtles 2: Battle Nexus              DS
# ...                                                  ...             ...
# 10874                                   Charlie's Angels        GameCube
# 10875                              Rambo: The Video Game   PlayStation 3
# 10876                           Fast & Furious: Showdown        Xbox 360
# 10877          Infestation: Survivor Stories (The War Z)              PC
# 10878                Leisure Suit Larry: Box Office Bust              PC
#
#            release_date                                            summary  \
# 10209      May 28, 2020  Those Who Remain is a psychological thriller g...
# 10210  February 5, 2008  Delivering all the excitement and fun of the e...
# 10211     June 24, 2014  Fight your way through both Earth and Cybertro...
# 10212  October 11, 2005  Play as your favorite Kids Next Door operative...
# 10213  October 19, 2004  The Teenage Mutant Ninja Turtles return--this ...
# ...                 ...                                                ...
# 10874      July 9, 2003  Join Natalie, Dylan, and Alex for an intense a...
# 10875    April 29, 2014  RAMBO The Vidoegame puts players in Rambo’s co...
# 10876      May 21, 2013  Fast & Furious: Showdown takes some of the fra...
# 10877  October 15, 2012  (Formerly known as "The War Z") It has been 5 ...
# 10878    March 31, 2009  The Leisure Suit Larry: Box Office Bust video ...
#
#        meta_score  user_review  \
# 10209          49          6.2
# 10210          49          6.9
# 10211          49          4.7
# 10212          49          8.0
# 10213          49          5.4
# ...           ...          ...
# 10874          23          4.3
# 10875          23          1.8
# 10876          22          1.3
# 10877          20          1.7
# 10878          20          2.0
#
#                                               ign_review  \
# 10209  Many of us have felt afraid of the dark at som...
# 10210  Sometimes we wonder how many little girls open...
# 10211  A Transformers game really only has to deliver...
# 10212  [Please note that this text was ported from a ...
# 10213  After the last Ninja Turtles outing, you'd thi...
# ...                                                  ...
# 10874  The new Charlie's Angels -- also known as Came...
# 10875  The legacy of Rambo is one of death, destructi...
# 10876  The Fast & Furious movies are known and loved ...
# 10877  When Hammerpoint Interactive announced The War...
# 10878  It was Codemasters that snagged this title fro...
#
#                                             clean_review  \
# 10209  Many of us have felt afraid of the dark at som...
# 10210  Sometimes we wonder how many little girls open...
# 10211  A Transformers game really only has to deliver...
# 10212  Please note that this text was ported from a r...
# 10213  After the last Ninja Turtles outing youd think...
# ...                                                  ...
# 10874  The new Charlies Angels  also known as Cameron...
# 10875  The legacy of Rambo is one of death destructio...
# 10876  The Fast  Furious movies are known and loved f...
# 10877  When Hammerpoint Interactive announced The War...
# 10878  It was Codemasters that snagged this title fro...
#
#                                            review_lowerc  \
# 10209  many of us have felt afraid of the dark at som...
# 10210  sometimes we wonder how many little girls open...
# 10211  a transformers game really only has to deliver...
# 10212  please note that this text was ported from a r...
# 10213  after the last ninja turtles outing youd think...
# ...                                                  ...
# 10874  the new charlies angels  also known as cameron...
# 10875  the legacy of rambo is one of death destructio...
# 10876  the fast  furious movies are known and loved f...
# 10877  when hammerpoint interactive announced the war...
# 10878  it was codemasters that snagged this title fro...
#
#                                             review_token  \
# 10209  [many, of, us, have, felt, afraid, of, the, da...
# 10210  [sometimes, we, wonder, how, many, little, gir...
# 10211  [a, transformers, game, really, only, has, to,...
# 10212  [please, note, that, this, text, was, ported, ...
# 10213  [after, the, last, ninja, turtles, outing, you...
# ...                                                  ...
# 10874  [the, new, charlies, angels, also, known, as, ...
# 10875  [the, legacy, of, rambo, is, one, of, death, d...
# 10876  [the, fast, furious, movies, are, known, and, ...
# 10877  [when, hammerpoint, interactive, announced, th...
# 10878  [it, was, codemasters, that, snagged, this, ti...
#
#                                         review_stopwords  \
# 10209  [many, us, felt, afraid, dark, point, lives, r...
# 10210  [sometimes, wonder, many, little, girls, open,...
# 10211  [transformers, game, really, deliver, two, sim...
# 10212  [please, note, text, ported, review, playstati...
# 10213  [last, ninja, turtles, outing, youd, think, po...
# ...                                                  ...
# 10874  [new, charlies, angels, also, known, cameron, ...
# 10875  [legacy, rambo, one, death, destruction, spent...
# 10876  [fast, furious, movies, known, loved, overthet...
# 10877  [hammerpoint, interactive, announced, war, z, ...
# 10878  [codemasters, snagged, title, dust, cloud, sur...
#
#                                           review_stemmed  \
# 10209  [mani, us, felt, afraid, dark, point, live, re...
# 10210  [sometim, wonder, mani, littl, girl, open, bir...
# 10211  [transform, game, realli, deliv, two, simpl, t...
# 10212  [pleas, note, text, port, review, playstat, 2,...
# 10213  [last, ninja, turtl, outing, youd, think, poss...
# ...                                                  ...
# 10874  [new, charli, angel, also, known, cameron, dia...
# 10875  [legaci, rambo, one, death, destruct, spent, m...
# 10876  [fast, furiou, movi, known, love, overthetop, ...
# 10877  [hammerpoint, interact, announc, war, z, excit...
# 10878  [codemast, snag, titl, dust, cloud, surround, ...
#
#                                        review_lemmatized  sentiment
# 10209  [many, u, felt, afraid, dark, point, life, rem...         -1
# 10210  [sometimes, wonder, many, little, girl, open, ...         -1
# 10211  [transformer, game, really, deliver, two, simp...         -1
# 10212  [please, note, text, ported, review, playstati...         -1
# 10213  [last, ninja, turtle, outing, youd, think, pos...         -1
# ...                                                  ...        ...
# 10874  [new, charlies, angel, also, known, cameron, d...         -1
# 10875  [legacy, rambo, one, death, destruction, spent...         -1
# 10876  [fast, furious, movie, known, loved, overtheto...         -1
# 10877  [hammerpoint, interactive, announced, war, z, ...         -1
# 10878  [codemasters, snagged, title, dust, cloud, sur...         -1
#
# [670 rows x 14 columns]

# %%
positive = data[data['sentiment'] == 1]
negative = data[data['sentiment'] == -1]

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

stopwords = STOPWORDS
stopwords.update(["game", "even", "one", "make", "time", "play", "character", "level", "player", "players",
                 "ways", "things", "take", "games", "wills", "way", "much", "fun", "will", "S", "well", "really",
                 "feel", "control", "enemy", "enemies", "characters", "really", "though", "point", "move",
                 "look", "gameplay", "little", "still", "story", "many", "back", "mission", "use", "first",
                 "actually", "around", "seem", "two", "come", "sound", "levels", "want", "mode", "playing",
                 "new", "see", "find", "weapon", "enough", "experience", "world", "lot", "need", "right",
                 "system", "go", "pretty", "serie", "bit", "set", "now", "fact", "world", "makes", 'may',
                 'released', 'always', 'alway', 'videogame', 'know', 'im', 'think', 'every', 'last',
                 'day'])

wordcloud2 = WordCloud(stopwords=stopwords, width=1600, height=800, max_font_size=200, background_color="black").generate(positive.review_lemmatized.to_string())
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis("off")
plt.savefig('wordcloudPositive.png')
plt.show()

# %%
stopwords = STOPWORDS
stopwords.update(["game", "even", "one", "make", "time", "play", "character", "level", "player", "players",
                 "ways", "things", "take", "games", "wills", "way", "much", "fun", "will", "S", "well", "really",
                 "feel", "control", "enemy", "enemies", "characters", "really", "though", "point", "move",
                 "look", "gameplay", "little", "still", "story", "many", "back", "mission", "use", "first",
                 "actually", "around", "seem", "two", "come", "sound", "levels", "want", "mode", "playing",
                 "new", "see", "find", "weapon", "enough", "experience", "world", "lot", "need", "right",
                 "system", "go", "pretty", "serie", "bit", "set", "now", "fact", "world", "makes", "good",
                 "every", "attack", "going", "title", 'released', 'series', 'im', 'saw', 'know', 'last', 'released',
                 'day', 'sport', 'often', 'videogame', 'u'])

wordcloud3 = WordCloud(stopwords=stopwords, width=1600, height=800, max_font_size=200, background_color="black").generate(negative.review_lemmatized.to_string())
plt.imshow(wordcloud3, interpolation='bilinear')
plt.axis("off")
plt.savefig('wordcloud33.png')
plt.show()

# %%
import numpy as np
index = data.index
data['random_number'] = np.random.randn(len(index))
train = data[data['random_number'] <= 0.8]
test = data[data['random_number'] > 0.8]
index
# Out:
# RangeIndex(start=0, stop=10879, step=1)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy import sparse


vectorizer = CountVectorizer(analyzer=lambda x: x)

X_train = sparse.hstack((vectorizer.fit_transform(train['review_lemmatized']),train[['meta_score']].values),format='csr')

X_test = sparse.hstack((vectorizer.transform(test['review_lemmatized']),test[['meta_score']].values),format='csr')

X2_columns=vectorizer.get_feature_names()+train[['review_lemmatized']].columns.tolist()

print(X_train.toarray())
print(X2_columns)
# Out:
# [[ 0  0  0 ...  0  0 99]
#  [ 0  0  0 ...  0  0 98]
#  [ 0  0  0 ...  0  0 98]
#  ...
#  [ 0  0  0 ...  0  0 22]
#  [ 0  0  0 ...  0  0 20]
#  [ 0  0  0 ...  0  0 20]]
# ['0', '00', '000', '0001', '000182', '007', '007s', '00s', '01', '010', '02', '03', '037', '03s', '04', '05', '0506', '06', '060', '06s', '07', '07s', '08', '08s', '09', '0910', '0910s', '099', '09s', '0fer', '0rigins', '1', '10', '100', '1000', '10000', '100000', '1000000', '10000th', '1000cc', '1000people', '1000point', '1001', '100100', '100200', '100cc', '100d', '100degree', '100foot', '100foottall', '100ft', '100hit', '100hour', '100ing', '100k', '100level', '100m', '100man', '100manslayer', '100meter', '100mph', '100page', '100percent', '100percenting', '100plus', '100point', '100second', '100stage', '100story', '100th', '100thug', '100ton', '100turn', '100x100', '100yards', '100year', '101', '1010', '1011', '1012', '1013', '1014', '1015', '10152015', '101plus', '101s', '101st', '102', '1020', '102025percent', '1024', '1024x720', '1024x768', '1024x768x16', '1024x768x32', '1024x768x32bit', '1028x764', '103', '1030', '1039', '104', '105', '1050', '105mm', '106', '1060', '10656', '1066', '107', '1070', '1070ti', '1078', '108', '1080', '1080i', '1080p', '1080p30fps', '1080p60fps', '1080powered', '1080style', '109', '109s', '10andunder', '10by10', '10chapter', '10character', '10enemy', '10floor', '10fold', '10foot', '10foottall', '10fps', '10game', '10gb', '10gun', '10health', '10hit', '10hour', '10hourlong', '10hourplus', '10ish', '10level', '10levels', '10m', '10man', '10meter', '10minute', '10ms', '10n', '10page', '10player', '10plus', '10plushour', '10round', '10season', '10second', '10spriteperline', '10stage', '10string', '10strings', '10strong', '10tall', '10th', '10tier', '10to', '10to1', '10to12', '10tons', '10turn', '10us', '10usd', '10v10', '10wave', '10week', '10x', '10x10', '10yard', '10year', '10yearold', '11', '110', '1100', '11000', '1100s', '110m', '111', '1112', '111213', '111objective', '111objectives', '112', '113', '113year', '114', '115', '1152x864', '116', '1162', '117', '117character', '118', '119', '1199', '11a', '11aside', '11bit', '11ghz', '11man', '11mission', '11month', '11on11', '11page', '11plus', '11style', '11th', '11v11', '11yearold', '11years', '12', '120', '1200', '12000', '120000', '1200car', '1200cc', '120130', '120fps', '120gig', '120hz', '120mph', '120x120', '1214', '1215', '1216', '122', '1221', '122474487139', '123', '1230', '1234', '123soldier', '124', '125', '1250', '125cc', '125ccs', '125hour', '125plus', '1274', '1275', '1278', '128', '1280', '1280x1024', '1280x1024x32', '1280x960', '12820', '128bit', '128mb', '128x', '1295', '1299', '12character', '12d', '12degree', '12digit', '12feet', '12foottall', '12frame', '12gauge', '12ghz', '12hit', '12hole', '12hour', '12inch', '12ish', '12ishhourlong', '12level', '12man', '12mile', '12mission', '12month', '12on12', '12orso', '12player', '12players', '12plus', '12stage', '12switch', '12th', '12thcentury', '12to6', '12v12', '12vs12', '12year', '12yearold', '12yearolds', '13', '130', '1300', '13000', '1300000', '130kmh', '131', '1320', '1328', '1333', '133page', '1340', '135', '135875', '136', '1366x768', '139', '13goal', '13hour', '13odd', '13rd', '13speed', '13th', '13year', '13yearold', '14', '140', '1400', '14000', '140000', '1400s', '140foot', '141', '1410', '1412758', '1415', '1419', '1420', '1421', '1426725', '1440p', '1444', '144hz', '144x144', '145', '1453', '145k', '1467', '147', '148150', '148mph', '149', '1499', '14999', '14a', '14b', '14car', '14character', '14country', '14floor', '14frame', '14game', '14gb', '14ghz', '14hour', '14level', '14mission', '14player', '14plus', '14th', '14will', '14year', '14yearold', '15', '150', '1500', '15000', '150000', '1500017000', '1500horsepower', '1500p', '1500s', '150200', '1503', '150cc', '150ft', '150gb', '150ish', '150k', '150mph', '150ms', '150player', '150plus', '150th', '150volley', '151', '1513', '1514', '1517', '152', '1520', '1520hour', '1522', '1525', '1527', '1530', '1539', '154', '1545', '155', '1561', '1575', '159', '1590', '1598', '1599', '15card', '15course', '15degree', '15 ...

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter=10000)

# %%
y_train = train['sentiment']
y_test = test['sentiment']

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
predictions = lr.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report
new = np.asarray(y_test)
confusion_matrix(predictions,y_test)
# Out:
# array([[ 136,    7],
#        [   1, 2197]])

# %%
print(classification_report(predictions,y_test))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.99      0.95      0.97       143
#            1       1.00      1.00      1.00      2198
#
#     accuracy                           1.00      2341
#    macro avg       0.99      0.98      0.98      2341
# weighted avg       1.00      1.00      1.00      2341

# %%
frames = [train, test]
result = pd.concat(frames)
result[['review_lemmatized', 'meta_score', 'user_review', 'sentiment']].to_csv('result.csv')
result
# Out:
#                                        name        platform  \
# 0      The Legend of Zelda: Ocarina of Time     Nintendo 64
# 1                  Tony Hawk's Pro Skater 2     PlayStation
# 3                               SoulCalibur       Dreamcast
# 6                      Super Mario Galaxy 2             Wii
# 8                        Grand Theft Auto V        Xbox One
# ...                                     ...             ...
# 10843         Mortal Kombat: Special Forces     PlayStation
# 10856                          KISS Pinball     PlayStation
# 10858         World War II Combat: Iwo Jima              PC
# 10860                            Game Party             Wii
# 10868  Gravity Games Bike: Street Vert Dirt   PlayStation 2
#
#              release_date                                            summary  \
# 0       November 23, 1998  As a young boy, Link is tricked by Ganondorf, ...
# 1      September 20, 2000  As most major publishers' development efforts ...
# 3       September 8, 1999  This is a tale of souls and swords, transcendi...
# 6            May 23, 2010  Super Mario Galaxy 2, the sequel to the galaxy...
# 8       November 18, 2014  Grand Theft Auto 5 melds storytelling and game...
# ...                   ...                                                ...
# 10843       June 30, 2000  Explore the world of Mortal Kombat! Play as th...
# 10856      April 25, 2001  KISS fans will be disappointed by the distinct...
# 10858       July 25, 2006  Relive the storied Marine assault that landed ...
# 10860   November 27, 2007  Game Party for the Wii is a collection of clas...
# 10868       June 27, 2002  Gravity Games Bike: Street. Vert. Dirt. delive...
#
#        meta_score  user_review  \
# 0              99          9.1
# 1              98          7.4
# 3              98          8.4
# 6              97          9.1
# 8              97          7.9
# ...           ...          ...
# 10843          28          2.8
# 10856          26          5.0
# 10858          26          3.4
# 10860          25          3.9
# 10868          24          3.4
#
#                                               ign_review  \
# 0      The new benchmark for interactive entertainmen...
# 1      I'm going to try to make this short and sweet,...
# 3      I'm reviewing Soul Calibur in a somewhat biase...
# 6      Not since the days of the Nintendo Entertainme...
# 8      When we reviewed Grand Theft Auto 5 on PlaySta...
# ...                                                  ...
# 10843  Here's a direct quote from the manual of Morta...
# 10856  I like pinball.  I like pinball a lot.  I used...
# 10858  We'll stay away from complaining that World Wa...
# 10860  If there's one thing we need on Wii, it's more...
# 10868  Once in a while, a game so good comes out that...
#
#                                             clean_review  \
# 0      The new benchmark for interactive entertainmen...
# 1      Im going to try to make this short and sweet b...
# 3      Im reviewing Soul Calibur in a somewhat biased...
# 6      Not since the days of the Nintendo Entertainme...
# 8      When we reviewed Grand Theft Auto 5 on PlaySta...
# ...                                                  ...
# 10843  Heres a direct quote from the manual of Mortal...
# 10856  I like pinball  I like pinball a lot  I used t...
# 10858  Well stay away from complaining that World War...
# 10860  If theres one thing we need on Wii its more ha...
# 10868  Once in a while a game so good comes out that ...
#
#                                            review_lowerc  \
# 0      the new benchmark for interactive entertainmen...
# 1      im going to try to make this short and sweet b...
# 3      im reviewing soul calibur in a somewhat biased...
# 6      not since the days of the nintendo entertainme...
# 8      when we reviewed grand theft auto 5 on playsta...
# ...                                                  ...
# 10843  heres a direct quote from the manual of mortal...
# 10856  i like pinball  i like pinball a lot  i used t...
# 10858  well stay away from complaining that world war...
# 10860  if theres one thing we need on wii its more ha...
# 10868  once in a while a game so good comes out that ...
#
#                                             review_token  \
# 0      [the, new, benchmark, for, interactive, entert...
# 1      [im, going, to, try, to, make, this, short, an...
# 3      [im, reviewing, soul, calibur, in, a, somewhat...
# 6      [not, since, the, days, of, the, nintendo, ent...
# 8      [when, we, reviewed, grand, theft, auto, 5, on...
# ...                                                  ...
# 10843  [heres, a, direct, quote, from, the, manual, o...
# 10856  [i, like, pinball, i, like, pinball, a, lot, i...
# 10858  [well, stay, away, from, complaining, that, wo...
# 10860  [if, theres, one, thing, we, need, on, wii, it...
# 10868  [once, in, a, while, a, game, so, good, comes,...
#
#                                         review_stopwords  \
# 0      [new, benchmark, interactive, entertainment, a...
# 1      [im, going, try, make, short, sweet, im, neith...
# 3      [im, reviewing, soul, calibur, somewhat, biase...
# 6      [since, days, nintendo, entertainment, system,...
# 8      [reviewed, grand, theft, auto, 5, playstation,...
# ...                                                  ...
# 10843  [heres, direct, quote, manual, mortal, kombat,...
# 10856  [like, pinball, like, pinball, lot, used, play...
# 10858  [well, stay, away, complaining, world, war, ii...
# 10860  [theres, one, thing, need, wii, halfassed, min...
# 10868  [game, good, comes, makes, take, new, apprecia...
#
#                                           review_stemmed  \
# 0      [new, benchmark, interact, entertain, arriv, l...
# 1      [im, go, tri, make, short, sweet, im, neither,...
# 3      [im, review, soul, calibur, somewhat, bias, st...
# 6      [sinc, day, nintendo, entertain, system, ninte...
# 8      [review, grand, theft, auto, 5, playstat, 3, x...
# ...                                                  ...
# 10843  [here, direct, quot, manual, mortal, kombat, s...
# 10856  [like, pinbal, like, pinbal, lot, use, play, l...
# 10858  [well, stay, away, complain, world, war, ii, c...
# 10860  [there, one, thing, need, wii, halfass, miniga...
# 10868  [game, good, come, make, take, new, appreci, g...
#
#                                        review_lemmatized  sentiment  \
# 0      [new, benchmark, interactive, entertainment, a...          1
# 1      [im, going, try, make, short, sweet, im, neith...          1
# 3      [im, reviewing, soul, calibur, somewhat, biase...          1
# 6      [since, day, nintendo, entertainment, system, ...          1
# 8      [reviewed, grand, theft, auto, 5, playstation,...          1
# ...                                                  ...        ...
# 10843  [here, direct, quote, manual, mortal, kombat, ...         -1
# 10856  [like, pinball, like, pinball, lot, used, play...         -1
# 10858  [well, stay, away, complaining, world, war, ii...         -1
# 10860  [there, one, thing, need, wii, halfassed, mini...         -1
# 10868  [game, good, come, make, take, new, appreciati...         -1
#
#        random_number
# 0          -0.855043
# 1           0.530401
# 3          -1.461860
# 6          -0.196732
# 8          -0.181516
# ...              ...
# 10843       0.956995
# 10856       1.266196
# 10858       1.353190
# 10860       1.838796
# 10868       2.071234
#
# [10879 rows x 15 columns]

# %%
index = result.index
result['random_number2'] = np.random.randn(len(index))
train2 = result[result['random_number2'] <= 0.8]
test2 = result[result['random_number2'] > 0.8]

X2_train = sparse.hstack((vectorizer.fit_transform(train2['review_lemmatized']),train2[['meta_score', 'sentiment']].values),format='csr')

X2_test = sparse.hstack((vectorizer.transform(test2['review_lemmatized']),test2[['meta_score', 'sentiment']].values),format='csr')

X3_columns=vectorizer.get_feature_names()+train2[['review_lemmatized']].columns.tolist()

print(X2_train.toarray())
print(X3_columns)
# Out:
# [[ 0  0  0 ...  0 98  1]
#  [ 0  0  0 ...  0 98  1]
#  [ 0  0  0 ...  0 97  1]
#  ...
#  [ 0  0  0 ...  0 26 -1]
#  [ 0  0  0 ...  0 25 -1]
#  [ 0  0  0 ...  0 24 -1]]
# ['0', '00', '000', '0001', '000182', '007', '0079', '007s', '00s', '01', '010', '02', '03', '037', '03s', '04', '05', '0506', '06', '06s', '07', '07s', '08', '08s', '08th', '09', '0910', '0910s', '099', '09s', '0fer', '0rigins', '1', '10', '100', '1000', '10000', '100000', '1000000', '1000cc', '1000people', '1000point', '1001', '100100', '100200', '100cc', '100d', '100floor', '100fold', '100foot', '100foottall', '100ft', '100hour', '100ing', '100k', '100level', '100m', '100man', '100manslayer', '100meter', '100minute', '100mph', '100page', '100part', '100percent', '100percenting', '100plus', '100point', '100second', '100stage', '100story', '100th', '100thug', '100turn', '100x100', '100yards', '100year', '101', '1010', '1011', '1012', '1013', '1014', '1015', '10152015', '101s', '101st', '102', '1020', '102025percent', '1024', '1024x720', '1024x768', '1024x768x16', '1024x768x32', '1024x768x32bit', '103', '1030', '104', '105', '1050', '105mm', '106', '1060', '10656', '1066', '107', '1070', '1070ti', '1078', '108', '1080', '1080i', '1080p', '1080p30fps', '1080p60fps', '1080powered', '1080s', '1080style', '109', '109s', '10andunder', '10by10', '10chapter', '10character', '10dollar', '10enemy', '10fold', '10foot', '10foottall', '10fps', '10game', '10gb', '10gun', '10health', '10hit', '10hour', '10hourlong', '10hourplus', '10ish', '10k', '10level', '10levels', '10m', '10man', '10meter', '10minute', '10month', '10ms', '10n', '10page', '10player', '10plus', '10plushour', '10round', '10season', '10second', '10spriteperline', '10stage', '10string', '10strings', '10tall', '10th', '10tier', '10to', '10to1', '10to12', '10tons', '10turn', '10usd', '10v10', '10week', '10x', '10x10', '10yard', '10year', '10yearold', '11', '110', '1100', '11000', '1100s', '110m', '111', '1112', '111213', '111objective', '111objectives', '112', '112page', '113', '113year', '114', '115', '116', '117', '117character', '118', '119', '11a', '11aside', '11bit', '11fps', '11ghz', '11mission', '11month', '11on11', '11page', '11plus', '11style', '11th', '11v11', '11x', '11yearold', '12', '120', '1200', '12000', '120000', '1200car', '1200cc', '120130', '120fps', '120gig', '120hz', '120mph', '120x120', '1214', '1215', '1216', '1217', '122', '1221', '122474487139', '123', '1230', '1234', '123soldier', '124', '125', '1250', '125cc', '125hour', '125plus', '1260', '1274', '1275', '1278', '128', '1280', '1280x1024', '1280x1024x32', '1280x960', '12820', '128bit', '128mb', '128x', '1295', '1299', '12ball', '12character', '12d', '12degree', '12digit', '12feet', '12frame', '12gauge', '12gb', '12ghz', '12hit', '12hole', '12hour', '12inch', '12ish', '12ishhourlong', '12man', '12mile', '12mission', '12month', '12on12', '12orso', '12player', '12players', '12plus', '12racer', '12round', '12second', '12stage', '12switch', '12th', '12thcentury', '12to6', '12v12', '12year', '12yearold', '12yearolds', '13', '130', '1300', '13000', '1300000', '130kmh', '131', '1320', '1328', '1333', '1340', '1346', '135', '135875', '136', '139', '13goal', '13hour', '13level', '13mission', '13odd', '13rd', '13speed', '13th', '13year', '13yearold', '13yearolds', '14', '140', '1400', '14000', '140000', '1400s', '140foot', '141', '1410', '1412758', '1415', '1420', '1421', '1426725', '144', '1440p', '144hz', '144x144', '145', '1453', '145k', '1467', '147', '148mph', '149', '1499', '14999', '14a', '14b', '14car', '14character', '14country', '14day', '14floor', '14frame', '14game', '14gb', '14ghz', '14hour', '14level', '14mission', '14player', '14plus', '14th', '14will', '14year', '14yearold', '15', '150', '1500', '15000', '150000', '1500017000', '1500horsepower', '1500p', '1500s', '150200', '1503', '150cc', '150ccs', '150ft', '150gb', '150ish', '150k', '150mph', '150ms', '150player', '150plus', '150th', '150volley', '151', '1513', '1514', '1517', '152', '1520', '1520hour', '1522', '1525', '1527', '1530', '1539', '154', '1540', '155', '1561', '1573', '159', '1590', '1598', '1599', '15card', '15chapter', '15course' ...

# %%
from sklearn.linear_model import LinearRegression
lr2 = LinearRegression()

# %%
y2_train = train2['user_review']
y2_test = test2['user_review']

# %%
lr2.fit(X2_train,y2_train)
# Out:
# LinearRegression()

# %%
predictions2 = lr2.predict(X2_test)

# %%
print(lr2.score(X2_test, y2_test))
# Out:
# 0.3284300436613713

# %%
test['predicted'] = pd.Series(predictions2)

test.head(50)
# Out:
# /var/folders/c8/8z1ylvms0f34n8g4t4sn4fn00000gn/T/ipykernel_4655/1995505693.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['predicted'] = pd.Series(predictions2)

# %%
test.to_csv('predicted_user_review.csv')
test[['name', 'platform', 'release_date', 'meta_score', 'user_review', 'predicted']].to_csv('predicted_user_review2.csv')
